# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
from ggplot import *
import numpy as np

# %% [markdown]
# <p> PGRNT_N = number of first year students receiving pell grants </p>
# <br>
# <p> PGRNT_P = percent of first year students receiving pell grants </p>

# %%
fa = pd.read_csv('sfa1314.csv')
fa.head()
# Out:
#    UNITID XSCUGRAD  SCUGRAD XSCUGFFN  SCUGFFN XSCUGFFP  SCUGFFP XSCFA2  \
# 0  100654        R     4051        R     1066        R       26      R
# 1  100663        R    11542        R     1732        R       15      R
# 2  100690        R      322        R        3        R        1      R
# 3  100706        R     5696        R      638        R       11      R
# 4  100724        R     5356        R     1520        R       28      R
#
#      SCFA2 XSCFA1N   ...     XNPT410  NPT410  XNPT420  NPT420  XNPT430 NPT430  \
# 0   4051.0       R   ...           A     NaN        A     NaN        A    NaN
# 1  11542.0       R   ...           A     NaN        A     NaN        A    NaN
# 2    322.0       R   ...           R  6332.0        R  8364.0        A    NaN
# 3   5696.0       R   ...           A     NaN        A     NaN        A    NaN
# 4   5356.0       R   ...           A     NaN        A     NaN        A    NaN
#
#    XNPT440 NPT440  XNPT450 NPT450
# ...

# %%
gr = pd.read_csv('gr200_14.csv')
gr.head()
# Out:
#    UNITID XBAREVCT  BAREVCT XBAEXCLU  BAEXCLU XBAAC150  BAAC150 XBANC100  \
# 0  100654        R   1133.0        R      0.0        R   1133.0        R
# 1  100663        R   1485.0        R      1.0        R   1484.0        R
# 2  100690        R      1.0        R      0.0        R      1.0        Z
# 3  100706        R    801.0        R      0.0        R    801.0        R
# 4  100724        R   1298.0        R      0.0        R   1298.0        R
#
#    BANC100 XBAGR100   ...     XL4AC200 L4AC200  XL4NC20A L4NC200A  XL4STEND  \
# 0    110.0        R   ...            A     NaN         A      NaN         A
# 1    378.0        R   ...            A     NaN         A      NaN         A
# 2      0.0        R   ...            A     NaN         A      NaN         A
# 3    128.0        R   ...            A     NaN         A      NaN         A
# 4    109.0        R   ...            A     NaN         A      NaN         A
#
#   L4STEND  XL4NC200 L4NC200  XL4GR200 L4GR200
# ...

# %%
fa.columns
# Out:
# Index(['UNITID', 'XSCUGRAD', 'SCUGRAD', 'XSCUGFFN', 'SCUGFFN', 'XSCUGFFP',
#        'SCUGFFP', 'XSCFA2', 'SCFA2', 'XSCFA1N',
#        ...
#        'XNPT410', 'NPT410', 'XNPT420', 'NPT420', 'XNPT430', 'NPT430',
#        'XNPT440', 'NPT440', 'XNPT450', 'NPT450  '],
#       dtype='object', length=647)

# %%
hd = pd.read_csv('hd2015.csv',encoding="ISO-8859-1")

# %%
hd.head()
# Out:
#    UNITID                               INSTNM  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
#    OBEREG                   CHFNM   CHFTITLE    ...      CSA  NECTA  F1SYSTYP  \
# 0       5  Dr. Andrew Hugine, Jr.  President    ...      290     -2         2
# 1       5            Ray L. Watts  President    ...      142     -2         1
# ...

# %%
data = pd.merge(hd, fa, left_on='UNITID', right_on='UNITID')

# %%
data.head()
# Out:
#    UNITID                               INSTNM  \
# 0  100654             Alabama A & M University
# 1  100663  University of Alabama at Birmingham
# 2  100690                   Amridge University
# 3  100706  University of Alabama in Huntsville
# 4  100724             Alabama State University
#
#                              ADDR        CITY STABBR         ZIP  FIPS  \
# 0            4900 Meridian Street      Normal     AL       35762     1
# 1  Administration Bldg Suite 1070  Birmingham     AL  35294-0110     1
# 2                  1200 Taylor Rd  Montgomery     AL  36117-3553     1
# 3                 301 Sparkman Dr  Huntsville     AL       35899     1
# 4            915 S Jackson Street  Montgomery     AL  36104-0271     1
#
#    OBEREG                   CHFNM   CHFTITLE   ...    XNPT410  NPT410  \
# 0       5  Dr. Andrew Hugine, Jr.  President   ...          A     NaN
# 1       5            Ray L. Watts  President   ...          A     NaN
# ...

# %%
data = pd.merge(data, gr, left_on='UNITID', right_on='UNITID')

# %%
datadf = data[['INSTNM','PGRNT_P','BAGR100','NPIS422','NPIS432']]

# %% [markdown]
# INSTNM = College name
# 1. PGRNT_P = % of first year students receiving pell grant
# SCUGFFN = Total number of full-time first-time degree/certificate seeking undergraduates - financial aid cohort
# 2. BAGR100 = 4-year Graduation rate - bachelor's degree within 100% of normal time
# 3. NPIS422 = Average net price (income 30,001-48,000)-students receiving Title IV Federal financial aid, 2013-14
# 4. NPIS432 = Average net price (income 48,001-75,000)-students receiving Title IV Federal financial aid, 2013-14

# %%
datadf.head()
# Out:
#                                 INSTNM  PGRNT_P  BAGR100  NPIS422  NPIS432
# 0             Alabama A & M University     80.0     10.0  14882.0  17479.0
# 1  University of Alabama at Birmingham     34.0     25.0  13703.0  16137.0
# 2                   Amridge University    100.0      0.0      NaN      NaN
# 3  University of Alabama in Huntsville     25.0     16.0  16849.0  19820.0
# 4             Alabama State University     71.0      8.0  11253.0  12817.0

# %%
datadf['index1'] = datadf['PGRNT_P'].multiply(datadf['BAGR100'], axis="index")
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
datadf.head()
# Out:
#                        INSTNM  PGRNT_P  BAGR100  NPIS422  NPIS432  index1
# 0               Allen College    100.0     79.0      NaN      NaN  7900.0
# 1      Briar Cliff University     43.0     35.0      NaN      NaN  1505.0
# 2      Buena Vista University     40.0     42.0      NaN      NaN  1680.0
# 3       Capri College-Dubuque     45.0      NaN      NaN      NaN     NaN
# 4  Capri College-Cedar Rapids     62.0      NaN      NaN      NaN     NaN

# %%
datadf['index2'] = datadf['NPIS422'] + datadf['NPIS432'] / 2
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
datadf.dropna()
# Out:
#                                                  INSTNM  PGRNT_P  BAGR100  \
# 0                              Alabama A & M University     80.0     10.0
# 1                   University of Alabama at Birmingham     34.0     25.0
# 3                   University of Alabama in Huntsville     25.0     16.0
# 4                              Alabama State University     71.0      8.0
# 5                             The University of Alabama     18.0     41.0
# 7                       Auburn University at Montgomery     51.0      1.0
# 8                                     Auburn University     13.0     38.0
# 26                        Jacksonville State University     45.0     10.0
# 32                           University of West Alabama     58.0     16.0
# 37                             University of Montevallo     38.0     21.0
# 39                          University of North Alabama     43.0     11.0
# 50                          University of South Alabama     42.0     14.0
# ...

# %%
datadf.head()
# Out:
#                                 INSTNM  PGRNT_P  BAGR100  NPIS422  NPIS432  \
# 0             Alabama A & M University     80.0     10.0  14882.0  17479.0
# 1  University of Alabama at Birmingham     34.0     25.0  13703.0  16137.0
# 2                   Amridge University    100.0      0.0      NaN      NaN
# 3  University of Alabama in Huntsville     25.0     16.0  16849.0  19820.0
# 4             Alabama State University     71.0      8.0  11253.0  12817.0
#
#    index1   index2
# 0   800.0  23621.5
# 1   850.0  21771.5
# 2     0.0      NaN
# 3   400.0  26759.0
# 4   568.0  17661.5

# %%
datadf['finalindex'] = (datadf['index1']/datadf['index1'].mean()) + (datadf['index2']/datadf['index2'].mean())
# Out:
# /usr/local/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
datadf = datadf.dropna()

# %%
datadf.sort_values('finalindex', ascending=False)
# Out:
#                                                  INSTNM  PGRNT_P  BAGR100  \
# 3709                  Puerto Rico Conservatory of Music     88.0     50.0
# 2269                          Morrisville State College     68.0     45.0
# 1982                                   Rowan University     28.0     49.0
# 224                     University of California-Irvine     47.0     66.0
# 1949                              Granite State College     72.0     33.0
# 2264               SUNY College of Technology at Alfred     55.0     44.0
# 1345                             Maine Maritime Academy     27.0     60.0
# 2267  SUNY College of Agriculture and Technology at ...     59.0     38.0
# 2959         University of Pittsburgh-Pittsburgh Campus     16.0     62.0
# 1998                         Montclair State University     40.0     35.0
# 3921                 Pennsylvania College of Technology     42.0     29.0
# 228              University of California-Santa Barbara     36.0     67.0
# ...
